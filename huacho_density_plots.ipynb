# %%
# %pylab inline
import pandas as pnd
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
huacho = pnd.read_csv('huacho.txt', skiprows=2, header='infer', index_col=0, sep='\t', parse_dates=True)

# %%
print 'end date   =', huacho.index.max()
print 'start date =', huacho.index.min()

ds = '2012-11-01'
de = '2013-01-08'
# Out:
# end date   = 2013-01-09 12:30:00
# start date = 2012-10-10 17:30:00

# %%
for i in range(len(huacho.columns)-1):
    huacho[huacho.columns[i]][ds:de].plot(kind='kde')
    title(huacho.columns[i])
    plt.show()
